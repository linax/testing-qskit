# %%
#Executing Qiskit locally with this notebook
from qiskit import *
from qiskit.visualization import plot_histogram, array_to_latex, plot_bloch_multivector
# %matplotlib inline

# %%
qr = QuantumRegister(1)
cr = ClassicalRegister(1)
circuit = QuantumCircuit(qr, cr)
circuit.h(0)
circuit.measure(qr, cr)

# %%
# UPDATE: Code updated after recording to resolve breaking changes from Qiskit 1.0
# Here we don't use AER  but Qiskit 1.0+ provides BasicProvider
# UPDATE: Code updated after recording to resolve breaking changes from Qiskit 1.0
circuit.remove_final_measurements()  # no measurements allowed
from qiskit.quantum_info import Statevector
statevector = Statevector(circuit)
array_to_latex(statevector)
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(statevector)
